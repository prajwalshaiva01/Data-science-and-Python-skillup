# %% [markdown]
# ### Input and Output in Python

# %%
print('Hello Word')
# Out:
# Hello Word

# %%
print ('my name is prajwal')
# Out:
# my name is prajwal

# %%
name= input("enter your name")
print("Hello my name is",name)
# Out:
# enter your name Shaiva
# Hello my name is Shaiva

# %%
I= "Prajwal"
print(I)
age=22
print(age)
city= "Hassan"
print(city)
# Out:
# Prajwal
# 22
# Hassan

# %%
print(I,age,city)
# Out:
# Prajwal 22 Hassan

# %%
x,y = input("Enter two values: ").split()
print("Number of boys: ",x)
print("Number of girls: ", y)
a, b, c = input("Enter three values: ").split()
print("Total number of students: ", a)
print("Number of boys is : ", b)
print("Number of girls is : ", c)
# Out:
# Enter two values:  50 50
# Number of boys:  50
# Number of girls:  50
# Enter three values:  100 50 50
# Total number of students:  100
# Number of boys is :  50
# Number of girls is :  50

# %%
color=input("What color is sky")
print(color)
# Out:
# What color is sky bule

# %%
num=int(input("enter a number"))
print(num)
# Out:
# enter a number 34
# 34

# %%
price=float(input("enter a number"))
print(price)
# Out:
# enter a number 45.5748
# 45.5748

# %%
a = "Hello World"
b = 10
c = 11.22
d = ("Prajwal shaiva")
e = ["Geeks", "for", "Geeks"]
f = {"Geeks": 1, "for":2, "Geeks":3}
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'tuple'>
# <class 'list'>
# <class 'dict'>

# %% [markdown]
# ## Python variables

# %%
x=5
name='prjwal'
print(x)
print(name)
print(x,name)
# Out:
# 5
# prjwal
# 5 prjwal

# %%
age=22
tatal_score=456
_color='red'
print(age)
print(tatal_score)
print(_color)
# Out:
# 22
# 456
# red

# %%
1name='prajwal' ## error
print(1name)
##variable only latters digit and _
# Out:
#   Cell In[5], line 1
#     1name='prajwal'
#     ^
# SyntaxError: invalid decimal literal

# %%
# Assining the values of vaiables
x=5
y=3.45
z='Hii'
print(x)
print(y)
print(z)
# Out:
# 5
# 3.45
# Hii

# %%
# Multiple Assignments
a=b=c=1000
print(a,b,c)
# Out:
# 1000 1000 1000

# %%
a=b=c=12,23,45
print(a,b,c)
# Out:
# (12, 23, 45) (12, 23, 45) (12, 23, 45)

# %%
a,b,c=24,5,56
print(a,b,c)
# Out:
# 24 5 56

# %%
x,y,z=23,34,"Prajwal Shaiva"
print(x,y,z)
# Out:
# 23 34 Prajwal Shaiva

# %%
# Type Casting Varible

# %%
s=12
n=int(s)
cnt=s
f=float(cnt)
age=22
s2=str(age)
print(n)
print(f)
print(s2)
# Out:
# 12
# 12.0
# 22

# %%
# Type of variable
n=22
f=23.34
s='name'
d={'key':'value'}
l=[1,2,3,4,5,5,]
print(type(n))
print(type(f))
print(type(s))
print(type(d))
print(type(l))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'dict'>
# <class 'list'>

# %%
# Deleting a variable
name=10
del name
print(name)

# %%
# swap variable
a,b=23,34
a,b=b,a
print(a,b)
# Out:
# 34 23

# %% [markdown]
# ### Python keyord

# %%
# Getting List of all python keywords
import keyword
print('List of python keywords are:')
print(keyword.kwlist)
# Out:
# List of python keywords are:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
s="Hello"
n=20
f=5.5
print(s)
print(n)
print(f)
# Out:
# Hello
# 20
# 5.5

# %%
s="hello"
print(s)
n=20
result=n+10
print(result)
f=5.5
result=f*10
print(result)
# Out:
# hello
# 30
# 55.0
