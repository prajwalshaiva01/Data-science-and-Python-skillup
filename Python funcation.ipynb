# %% [markdown]
# ## Python funcation

# %%
def fun():
   print ("helloword")
fun()
# Out:
# helloword

# %%
def evenodd(x):
   if(x%2==0):
    return "even"
   else:
     return "odd"
print(evenodd(16))
print(evenodd(15))
# Out:
# even
# odd

# %% [markdown]
# ### defult funcation

# %%
def myfun (x,y=90):
    print("x:",x)
    print("y:",y)
myfun(10)
# Out:
# x: 10
# y: 90

# %% [markdown]
# ### keywords arguments

# %%
def student(fname,lname):
    print(fname,lname)
student(fname='prjwal',lname='shaiva')
# Out:
# prjwal shaiva

# %% [markdown]
# ### positional arguments

# %%
def nameage(name,age):
    print('hii i am',name)
    print('my age is',age)
print('case-1:')
nameage('prajwal',22)
print('case-2:')
nameage('shaiva',23)
# Out:
# case-1:
# hii i am prajwal
# my age is 22
# case-2:
# hii i am shaiva
# my age is 23

# %% [markdown]
# ## Lambda funcation

# %%
a='prajwal'
upper=lambda x: x.upper()
print(upper(a))
# Out:
# PRAJWAL

# %%
 lam=lambda x:"positive" if x>0 else "Negative" if <0 else"Zero"
