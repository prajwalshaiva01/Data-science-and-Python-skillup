# %% [markdown]
#  ## Python Data type

# %%
x=20 # int
x=3.44 # flot
x=['name','prajwal'] # list
x="hell" # string
x=('hello','name') # tupel

# %% [markdown]
# ### Numaric Data type

# %%
a=23
b=584.35
c=2+3j
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# ### Sequence Data type

# %%
s='my name is prajwal'
print(s)
print(type(s))
print(s[0])
print(s[1])
print(s[1])
print(s[3])
# Out:
# my name is prajwal
# <class 'str'>
# m
# y
# y
# n

# %% [markdown]
# ### List Data type

# %%
a=[1,2,3,4,5,6,7,8,9,0]
print(a)
b=['prjwal','shaiva']
print(b)
print(type(a))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]
# ['prjwal', 'shaiva']
# <class 'list'>

# %%
a=['Hassan','arkalgudu','beluru','mysuru']
print(a[0])
print(a[-1])
# Out:
# Hassan
# mysuru

# %% [markdown]
# ### Tupel Data type

# %%
tup1=()
tup2=('prajwal','shaiva')
print("\ntuple with the use of string:",tup2)
# Out:
# tuple with the use of string: ('prajwal', 'shaiva')

# %% [markdown]
# ### Bolean Data type

# %%
print(type(True))
print(type(False))
# Out:
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# ### Truthy and Falsy Value

# %%
if 1:
    print('1 is true')
if not 0:
        print('0 is false')
# Out:
# 1 is true
# 0 is false

# %% [markdown]
# ### set  data type

# %%
s1=set()
s1=set("prjwal shavia")
print('set data type date',s1)
s2=('prajwal','shaiva')
print('set data type date',s2)
# Out:
# set data type date {'i', 'p', ' ', 'h', 's', 'w', 'j', 'l', 'v', 'r', 'a'}
# set data type date ('prajwal', 'shaiva')

# %% [markdown]
# ### Dictionary Data type

# %%
d={}
d={1:'prajwal',2:'shaiva',3:'kiran'}
print(d)
# Out:
# {1: 'prajwal', 2: 'shaiva', 3: 'kiran'}
