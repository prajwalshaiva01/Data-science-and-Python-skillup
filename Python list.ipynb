# %%
a=[1,2,3,4,5,6]
b=['prajwal','kiran','drashan']
print(a)
print(b)
# Out:
# [1, 2, 3, 4, 5, 6]
# ['prajwal', 'kiran', 'drashan']

# %%
a=list((1,22,3,4,5,6,7,8))
print(a)
# Out:
# [1, 22, 3, 4, 5, 6, 7, 8]

# %%
a=list(("prajwal"))
print(a)
# Out:
# ['p', 'r', 'a', 'j', 'w', 'a', 'l']

# %%
a=[2]*5
b=[4]*4
print(a)
print(b)
# Out:
# [2, 2, 2, 2, 2]
# [4, 4, 4, 4]

# %%
a=[10,2,3,4,5,67,89,90]
print(a[0])
print(a[2])
print(a[-5])
print(a[1:3])
# Out:
# 10
# 3
# 4
# [2, 3]

# %%
a=[12,23,34,45,56]
a.append(100)
print(a)
# Out:
# [12, 23, 34, 45, 56, 100]

# %%
a=[12,23,34,45,56]
a.insert(2,0)
print(a)
# Out:
# [12, 23, 0, 34, 45, 56]

# %%
a=[12,23,34,45,56]
a.extend([36,78])
print(a)
# Out:
# [12, 23, 34, 45, 56, 36, 78]

# %%
a=[12,23,34,45,56]
a.clear()
print(a)
# Out:
# []

# %%
a=[12,23,34,45,56,78]
a[1]=11
print(a)
# Out:
# [12, 11, 34, 45, 56, 78]

# %%
a=[1,2,3,4,5,6,7,8,9]
a[3]=30
print(a)
# Out:
# [1, 2, 3, 30, 5, 6, 7, 8, 9]

# %%
a=[1,2,3,4,5,6,7,8,9]
a.remove(2)
print(a)
# Out:
# [1, 3, 4, 5, 6, 7, 8, 9]

# %%
a=['prajwal','kiran','darshan']
for item in a:
    print(item)
# Out:
# prajwal
# kiran
# darshan

# %%
a=['prajwal','kiran','darshan']
for char in a:
    print(char)
# Out:
# prajwal
# kiran
# darshan

# %%
a=([1,2,3],
   [2,3,4],
   [4,5,6])
print(a)
# Out:
# ([1, 2, 3], [2, 3, 4], [4, 5, 6])

# %%
a=([1,2,3],
   [2,3,4],
   [4,5,6])
print(a[1][2])
# Out:
# 4

# %%
a=[1,2,3]
a.append([4,5])
print(a)
# Out:
# [1, 2, 3, [4, 5]]

# %%
b=range(100,100)
print('fgdfgsyfgdf:',b.index(105))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 b=range(100,100)
# ----> 2 print('fgdfgsyfgdf:',b.index(105))
#
# ValueError: 105 is not in range

# %%
t1=(1)
t2=(3,4)
t1 +=5
print(t1)
print(t1 + t2)
# Out:
# 6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 5
#       3 t1 +=5
#       4 print(t1)
# ----> 5 print(t1 + t2)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
s='python'
print(s[1:4])
# Out:
# yth

# %%
print('geeksforgeeks'.split('ee',1))
# Out:
# ['g', 'ksforgeeks']
