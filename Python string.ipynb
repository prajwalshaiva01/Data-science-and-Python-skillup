# %%
s='prajwal'
s1='shaiva'
print(s)
# Out:
# prajwal

# %%
print(s1)
# Out:
# shaiva

# %% [markdown]
# #### multi line string

# %%
s='''I am larning python'''
print(s)
s='''I am prajwal'''
print(s)
# Out:
# I am larning python
# I am prajwal

# %%
s="Prjwal"
print(s[0])
print(s[1])
print(s[2])
print(s[3])
# Out:
# P
# r
# j
# w

# %%
s="Prjwal"
print(s[-1])
print(s[-2])
print(s[-3])
print(s[-4])
# Out:
# l
# a
# w
# j

# %%
s='Prajwal'
print(s[1:3])
print(s[2:4])
# Out:
# ra
# aj

# %% [markdown]
# ### string lteration

# %%
s="pyathon"
for char in s:
   print(char)
# Out:
# p
# y
# a
# t
# h
# o
# n

# %%
s='prajwal'
s='P'+s[1:]
print(s)
# Out:
# Prajwal

# %%
s='prajwal'
print(len(s))
# Out:
# 7

# %%
s='Prajwal'
print(s.upper())
print(s.lower())
# Out:
# PRAJWAL
# prajwal

# %%
s='python is fun'
print(s)
print(s.replace('fun','awesome'))
# Out:
# python is fun
# python is awesome

# %%
s1='prajwal'
s2='shaiva'
print(s1 +' ' +s2)
# Out:
# prajwal shaiva

# %%
s='prajwal'
print(s * 5)
# Out:
# prajwalprajwalprajwalprajwalprajwal

# %%
name='prajwal'
age='22'
print(f'name:{name},age:{age}')
# Out:
# name:prajwal,age:22

# %%
s='prajwal'
print('p' in s)
print('e' in s
# Out:
# True
